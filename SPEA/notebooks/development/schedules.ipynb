# %% [markdown]
# # Template Notebook

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Standard library imports

# %%
# %load_ext autoreload

# %%
import sys
import warnings
import logging

sys.path.append('../..')
warnings.filterwarnings('ignore')
logger = logging.getLogger(__name__)

# %%
# %autoreload 2

import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

from source.utils import array_subset
from source.operators.schedules import (
    const_schedule,
    decreasing_linear_schedule,
    increasing_linear_schedule
)

# %% [markdown]
# ### Paths

# %%
sns.set()

# %%
n_generations = 100
t = np.arange(n_generations)

# %%
plt.figure(figsize=[20, 8])

_ = plt.plot(t, np.apply_along_axis(const_schedule, 1, t.reshape(-1,1), 0.4, 100))
_ = plt.plot(t, np.apply_along_axis(increasing_linear_schedule, 1, t.reshape(-1,1), 0.4, 100))
_ = plt.plot(t, np.apply_along_axis(decreasing_linear_schedule, 1, t.reshape(-1,1), 0.4, 100))
